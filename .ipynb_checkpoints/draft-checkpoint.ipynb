# %% [markdown]
# # Introduction

# %% [markdown]
# ## Motivation

# %% [markdown]
# The 2015 European migration crisis was a significant event that had a profound impact on political landscapes across the continent. Understanding how this crisis influenced public sentiment towards the EU is crucial for comprehending the broader political consequences, including shifts in voter preferences, party politics, and policy-making.
#
# We hope investigate how the 2015 migrations affected the support level towards EU over time by examining various factors such as the percentage of votes gained by each party, _______.

# %% [markdown]
# ## Goal

# %% [markdown]
# Research question: How did the 2015 european migration affect the support level towards EU?

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# We performed the following steps to prepare our data for analysis:
#
# 1. Select relevant columns
# 2. Convert dataframe column types
# 3. Handle missing values

# %%
import pandas as pd

# %%
#load the data
df = pd.read_csv('mp.csv', low_memory=False)
df
# Out:
#       country   countryname  oecdmember  eumember       edate    date   party  \
# 0          11        Sweden           0       0.0  17/09/1944  194409   11220
# 1          11        Sweden           0       0.0  17/09/1944  194409   11320
# 2          11        Sweden           0       0.0  17/09/1944  194409   11420
# 3          11        Sweden           0       0.0  17/09/1944  194409   11620
# 4          11        Sweden           0       0.0  17/09/1944  194409   11810
# ...       ...           ...         ...       ...         ...     ...     ...
# 5084      181  South Africa           0       0.0  08/05/2019  201905  181510
# 5085      181  South Africa           0       0.0  08/05/2019  201905  181520
# 5086      181  South Africa           0       0.0  08/05/2019  201905  181710
# 5087      181  South Africa           0       0.0  08/05/2019  201905  181910
# 5088      181  South Africa           0       0.0  08/05/2019  201905  181980
#
#                                partyname partyabbrev  parfam  ... per608_3  \
# 0              Communist Party of Sweden         SKP      20  ...      NaN
# 1         Social Democratic Labour Party         SAP      30  ...      NaN
# 2                         People’s Party          FP      40  ...      NaN
# 3                            Right Party         NaN      60  ...      NaN
# 4                         Agrarian Party         NaN      80  ...      NaN
# ...                                  ...         ...     ...  ...      ...
# 5084  African Christian Democratic Party        ACDP      50  ...      0.0
# 5085     African Transformation Movement         ATM      50  ...      0.0
# 5086                  Freedom Front Plus         FF+      70  ...      0.0
# 5087               Inkatha Freedom Party         IFP      90  ...      0.0
# 5088        African Independent Congress         AIC      90  ...      0.0
#
#       per703_1  per703_2    rile  planeco  markeco  welfare  intpeace  \
# 0          NaN       NaN   9.600    1.900    1.900    0.000     1.900
# 1          NaN       NaN -37.800    3.300    2.200   33.400     5.600
# 2          NaN       NaN   9.500    3.200    6.400   14.300     1.600
# 3          NaN       NaN  28.000    1.800   22.800   10.600     0.000
# 4          NaN       NaN  23.810    0.000   19.048    0.000     4.762
# ...        ...       ...     ...      ...      ...      ...       ...
# 5084     5.000       0.0  12.500    0.833    7.500   14.167     0.000
# 5085     1.042       0.0  -6.771    3.385    1.042   22.135     1.562
# 5086     3.497       0.0  19.580    0.699   10.664   11.364     0.000
# 5087     3.289       0.0  -6.579    0.658    0.658   28.947     0.000
# 5088     3.871       0.0 -14.839    2.581    0.000   24.516     0.000
#
#       datasetversion  id_perm
# 0              2023a   JN1LZH
# 1              2023a   CMR7F6
# 2              2023a   Z6OL6C
# 3              2023a   YMKVN2
# 4              2023a   U4SCRD
# ...              ...      ...
# 5084           2023a   HSQT6Y
# 5085           2023a   B6QCSE
# 5086           2023a   OS725O
# 5087           2023a   XKM7J7
# 5088           2023a   GC57QF
#
# [5089 rows x 175 columns]

# %% [markdown]
# Selecting relevant columns

# %%
df = df[["countryname", "edate", "eumember", "pervote", "per108", "per109", "per110", "per607", "per601_2", "per602_2", "per7062"]]

# %%
#select countries that are EU members
eu_df = df[df['eumember']==10]
eu_df
# Out:
#      countryname       edate  eumember  pervote  per108  per109  per110  \
# 92        Sweden  21/09/1998      10.0    4.500   0.000   0.000   9.722
# 93        Sweden  21/09/1998      10.0   11.990   0.000   0.000   3.323
# 94        Sweden  21/09/1998      10.0   36.390   4.688   0.000   0.000
# 95        Sweden  21/09/1998      10.0    4.720   3.571   0.000   0.000
# 96        Sweden  21/09/1998      10.0   11.770   0.599   0.000   0.000
# ...          ...         ...       ...      ...     ...     ...     ...
# 4602    Slovenia  03/06/2018      10.0    5.105   1.261   0.000   0.840
# 4603    Slovenia  03/06/2018      10.0    9.748   4.724   0.000   0.000
# 4604    Slovenia  03/06/2018      10.0    7.159   1.153   0.000   0.040
# 4605    Slovenia  03/06/2018      10.0    4.173   0.000   5.556   0.794
# 4606    Slovenia  03/06/2018      10.0    4.925   1.342   0.000   0.000
#
#       per607  per601_2  per602_2  per7062
# 92     0.000       NaN       NaN      0.0
# 93     0.000       NaN       NaN      0.0
# 94     0.000       NaN       NaN      0.0
# 95     0.000       NaN       NaN      0.0
# 96     0.000       NaN       NaN      0.0
# ...      ...       ...       ...      ...
# 4602   0.000     0.000      0.00      0.0
# 4603   0.000     0.000      0.00      0.0
# 4604   0.119     1.312      0.04      0.0
# 4605   0.000     3.968      0.00      0.0
# 4606   0.000     1.007      0.00      0.0
#
# [1852 rows x 11 columns]

# %% [markdown]
# Convert dataframe column types

# %%
eu_df['edate'] = pd.to_datetime(eu_df['edate'])
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_15652\1058144705.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eu_df['edate'] = pd.to_datetime(eu_df['edate'])

# %% [markdown]
# Replace missing values

# %%
eu_df.fillna(0,inplace=True)
eu_df
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_15652\862182475.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eu_df.fillna(0,inplace=True)
#      countryname      edate  eumember  pervote  per108  per109  per110  \
# 92        Sweden 1998-09-21      10.0    4.500   0.000   0.000   9.722
# 93        Sweden 1998-09-21      10.0   11.990   0.000   0.000   3.323
# 94        Sweden 1998-09-21      10.0   36.390   4.688   0.000   0.000
# 95        Sweden 1998-09-21      10.0    4.720   3.571   0.000   0.000
# 96        Sweden 1998-09-21      10.0   11.770   0.599   0.000   0.000
# ...          ...        ...       ...      ...     ...     ...     ...
# 4602    Slovenia 2018-03-06      10.0    5.105   1.261   0.000   0.840
# 4603    Slovenia 2018-03-06      10.0    9.748   4.724   0.000   0.000
# 4604    Slovenia 2018-03-06      10.0    7.159   1.153   0.000   0.040
# 4605    Slovenia 2018-03-06      10.0    4.173   0.000   5.556   0.794
# 4606    Slovenia 2018-03-06      10.0    4.925   1.342   0.000   0.000
#
#       per607  per601_2  per602_2  per7062
# 92     0.000     0.000      0.00      0.0
# 93     0.000     0.000      0.00      0.0
# 94     0.000     0.000      0.00      0.0
# 95     0.000     0.000      0.00      0.0
# 96     0.000     0.000      0.00      0.0
# ...      ...       ...       ...      ...
# 4602   0.000     0.000      0.00      0.0
# 4603   0.000     0.000      0.00      0.0
# 4604   0.119     1.312      0.04      0.0
# 4605   0.000     3.968      0.00      0.0
# 4606   0.000     1.007      0.00      0.0
#
# [1852 rows x 11 columns]

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Visualizing the percentage of votes gained by each party over time

# %%
pervote = eu_df.groupby('edate')['pervote'].mean().to_frame()
pervote
# Out:
#               pervote
# edate
# 1952-06-25  17.339400
# 1953-06-09  15.576167
# 1953-07-06  12.910857
# 1954-05-30  24.425000
# 1954-11-04  23.742250
# ...               ...
# 2019-12-12   9.635300
# 2020-05-07   8.517636
# 2020-11-10  10.991557
# 2021-03-17   5.765554
# 2021-09-26  13.060000
#
# [253 rows x 1 columns]

# %%
# Creating a line graph to see the change in percentage of votes gained by each party over the years. 
plt.figure(figsize=(20, 5))
plt.plot(pervote.index, pervote['pervote'], color='blue')
